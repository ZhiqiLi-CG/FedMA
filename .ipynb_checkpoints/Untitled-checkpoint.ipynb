# %%
# !python main.py --model=moderate-cnn \
--dataset=cifar10  \
--lr=0.01  \
--retrain_lr=0.01  \
--batch-size=64  \
--epochs=20  \
--retrain_epochs=10  \
--n_nets=16  \
--partition=hetero-dir  \
--comm_type=fedma  \
--comm_round=6  \
--retrain=True  \
--rematching=True
# Out:
# INFO:root:cuda:0
# args Namespace(batch_size=64, comm_round=6, comm_type='fedma', dataset='cifar10', epochs=20, fine_tune_epochs=10, fine_tune_lr=0.1, local_points=5000, lr=0.01, model='moderate-cnn', n_nets=16, oneshot_matching=False, partition='hetero-dir', partition_step=0, partition_step_size=6, prune_rate=0.0, rematching=True, retrain=True, retrain_epochs=10, retrain_lr=0.01, seed=0)
# INFO:root:Partitioning data
# Files already downloaded and verified
# Files already downloaded and verified
# INFO:root:averaging_weights: [[1.082e-01 4.260e-02 6.800e-03 3.580e-02 2.600e-03 1.980e-02 4.000e-03
#   7.400e-03 2.140e-02 3.780e-02]
#  [1.800e-03 6.000e-04 1.840e-02 4.000e-03 8.760e-02 3.164e-01 5.800e-03
#   2.316e-01 0.000e+00 0.000e+00]
#  [1.000e-03 2.380e-02 1.280e-02 9.220e-02 8.620e-02 1.506e-01 4.160e-02
#   2.000e-04 1.400e-03 1.800e-03]
#  [4.500e-02 2.960e-02 2.870e-01 1.000e-03 5.400e-03 2.170e-01 2.200e-03
#   2.240e-02 3.400e-02 0.000e+00]
# ...
